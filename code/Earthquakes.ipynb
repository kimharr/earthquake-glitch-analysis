# %%
import pandas as pd

# %%
aprilweekone = pd.read_csv('../data/AprilWeekOne.csv', parse_dates = ['time'])

# %%
aprilweekone = aprilweekone.sort_values('time', ascending = True).reset_index()

# %%
aprilweekone.head()
# Out:
#    index                             time  latitude   longitude  depth   mag  \
# 0   3048 2019-04-01 00:03:43.547000+00:00    7.8060   94.364000  10.00  5.00
# 1   3047 2019-04-01 00:04:50.917000+00:00   66.3021 -157.300400   6.40  2.00
# 2   3046 2019-04-01 00:05:05.828000+00:00   60.7779 -151.489100  65.50  1.10
# 3   3045 2019-04-01 00:10:22.870000+00:00   33.7025 -116.716333  16.88  0.79
# 4   3044 2019-04-01 00:11:01.449000+00:00   61.3792 -150.036900  41.00  0.80
#
#   magType   nst   gap      dmin  ...                   updated  \
# 0     mww   NaN  26.0  3.625000  ...  2019-06-08T20:51:28.040Z
# 1      ml   NaN   NaN       NaN  ...  2019-08-05T18:20:38.495Z
# 2      ml   NaN   NaN       NaN  ...  2019-08-05T18:20:38.187Z
# 3      ml  20.0  47.0  0.008831  ...  2019-04-01T00:22:49.383Z
# 4      ml   NaN   NaN       NaN  ...  2019-08-05T18:20:38.769Z
#
#                           place        type horizontalError depthError  \
# ...

# %%
aprilweekone_edited = aprilweekone[['time', 'latitude', 'longitude', 'depth','mag', 'magError', 'depthError','horizontalError', 'status']]

# %%
aprilweekone_edited.head()
# Out:
#                               time  latitude   longitude  depth   mag  \
# 0 2019-04-01 00:03:43.547000+00:00    7.8060   94.364000  10.00  5.00
# 1 2019-04-01 00:04:50.917000+00:00   66.3021 -157.300400   6.40  2.00
# 2 2019-04-01 00:05:05.828000+00:00   60.7779 -151.489100  65.50  1.10
# 3 2019-04-01 00:10:22.870000+00:00   33.7025 -116.716333  16.88  0.79
# 4 2019-04-01 00:11:01.449000+00:00   61.3792 -150.036900  41.00  0.80
#
#    magError  depthError  horizontalError    status
# 0     0.069        1.80             7.30  reviewed
# 1       NaN        0.30              NaN  reviewed
# 2       NaN        0.60              NaN  reviewed
# 3     0.145        0.76             0.63  reviewed
# 4       NaN        0.50              NaN  reviewed
